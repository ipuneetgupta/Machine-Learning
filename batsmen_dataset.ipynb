# %%
import json
import requests
def extractData(url):
    payload = {}
    headers= {}
    response = requests.request("GET", url, headers=headers, data = payload)
    return response.text
# Out:
# /home/puneet/.local/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
data = json.loads(extractData("https://win11.neolen.com/api/match-full"))
playersDetail = json.loads(extractData("https://win11.neolen.com/api/player-full"))

# %%
ipl = list()
for x in data[477:]:
  ipl.append(x)
len(ipl)
# Out:
# 639

# %%
ipl[136]
# Out:
# {'id': 1253,
#  'match_score': [{'id': 2505,
#    'batmens': [{'id': 19451,
#      'order': 1,
#      'runs': 48,
#      'balls': 43,
#      'strike_rate': 111.62,
#      'fours': 5,
#      'sixes': 1,
#      'how_out': 'b McClenaghan',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 118,
#      'scorecard': 2505},
#     {'id': 19452,
#      'order': 2,
#      'runs': 49,
#      'balls': 34,
#      'strike_rate': 144.11,
#      'fours': 7,
#      'sixes': 2,
#      'how_out': 'c †Patel b Harbhajan Singh',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 60,
#      'scorecard': 2505},
#     {'id': 19453,
#      'order': 3,
#      'runs': 9,
#      'balls': 9,
#      'strike_rate': 100.0,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'c Pollard b Harbhajan Singh',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1581,
#      'scorecard': 2505},
#     {'id': 19454,
#      'order': 4,
#      'runs': 5,
#      'balls': 7,
#      'strike_rate': 71.42,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'b HH Pandya',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 760,
#      'scorecard': 2505},
#     {'id': 19455,
#      'order': 5,
#      'runs': 20,
#      'balls': 10,
#      'strike_rate': 200.0,
#      'fours': 4,
#      'sixes': 0,
#      'how_out': 'b Bumrah',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 781,
#      'scorecard': 2505},
#     {'id': 19456,
#      'order': 6,
#      'runs': 9,
#      'balls': 9,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'c Pollard b Bumrah',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1407,
#      'scorecard': 2505},
#     {'id': 19457,
#      'order': 7,
#      'runs': 1,
#      'balls': 2,
#      'strike_rate': 50.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'c Rana b Malinga',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 359,
#      'scorecard': 2505},
#     {'id': 19458,
#      'order': 8,
#      'runs': 2,
#      'balls': 4,
#      'strike_rate': 50.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'c & b Bumrah',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 33,
#      'scorecard': 2505},
#     {'id': 19459,
#      'order': 9,
#      'runs': 4,
#      'balls': 3,
#      'strike_rate': 133.33,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 353,
#      'scorecard': 2505},
#     {'id': 19460,
#      'order': 10,
#      'runs': 0,
#      'balls': 0,
#      'strike_rate': 0.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 762,
#      'scorecard': 2505}],
#    'bowlers': [{'id': 13774,
#      'order': 1,
#      'run_conceded': 23,
#      'maidens': 0,
#      'wickets': 2,
#      'overs': 4.0,
#      'economy': 5.75,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 3,
#      'sixes': 1,
#      'zeros': 15,
#      'player': 829,
#      'scorecard': 2505},
#     {'id': 13775,
#      'order': 2,
#      'run_conceded': 30,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 7.5,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 4,
#      'sixes': 0,
#      'zeros': 9,
#      'player': 406,
#      'scorecard': 2505},
#     {'id': 13776,
#      'order': 3,
#      'run_conceded': 24,
#      'maidens': 0,
#      'wickets': 3,
#      'overs': 4.0,
#      'economy': 6.0,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 2,
#      'sixes': 0,
#      'zeros': 9,
#      'player': 117,
#      'scorecard': 2505},
#     {'id': 13777,
#      'order': 4,
#      'run_conceded': 42,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 10.5,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 6,
#      'sixes': 1,
#      'zeros': 7,
#      'player': 719,
#      'scorecard': 2505},
#     {'id': 13778,
#      'order': 5,
#      'run_conceded': 22,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 3.0,
#      'economy': 7.33,
#      'wides': 3,
#      'no_balls': 0,
#      'fours': 2,
#      'sixes': 1,
#      'zeros': 10,
#      'player': 125,
#      'scorecard': 2505},
#     {'id': 13779,
#      'order': 6,
#      'run_conceded': 12,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 1.0,
#      'economy': 12.0,
#      'wides': 1,
#      'no_balls': 1,
#      'fours': 1,
#      'sixes': 0,
#      'zeros': 0,
#      'player': 526,
#      'scorecard': 2505}],
#    'is_declared': True,
#    'wicket': 8,
#    'run': 158,
#    'extra': 11,
#    'bye': 0,
#    'leg_bye': 5,
#    'wide': 5,
#    'no_ball': 1,
#    'over': 20.0,
#    'run_rate': 7.9,
#    'required_run_rate': None,
#    'first_batting': True,
#    'team': 58,
#    'match': 1253},
#   {'id': 2506,
#    'batmens': [{'id': 19461,
#      'order': 1,
#      'runs': 39,
#      'balls': 24,
#      'strike_rate': 162.5,
#      'fours': 7,
#      'sixes': 0,
#      'how_out': 'c Kumar b Hooda',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1332,
#      'scorecard': 2506},
#     {'id': 19462,
#      'order': 2,
#      'runs': 14,
#      'balls': 11,
#      'strike_rate': 127.27,
#      'fours': 3,
#      'sixes': 0,
#      'how_out': 'b Nehra',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 94,
#      'scorecard': 2506},
#     {'id': 19463,
#      'order': 3,
#      'runs': 4,
#      'balls': 4,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'lbw b Rashid Khan',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 132,
#      'scorecard': 2506},
#     {'id': 19465,
#      'order': 4,
#      'runs': 45,
#      'balls': 36,
#      'strike_rate': 125.0,
#      'fours': 3,
#      'sixes': 2,
#      'how_out': 'b Kumar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1517,
#      'scorecard': 2506},
#     {'id': 19467,
#      'order': 5,
#      'runs': 11,
#      'balls': 11,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 1,
#      'how_out': 'c Dhawan b Kumar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 432,
#      'scorecard': 2506},
#     {'id': 19469,
#      'order': 6,
#      'runs': 37,
#      'balls': 20,
#      'strike_rate': 185.0,
#      'fours': 3,
#      'sixes': 3,
#      'how_out': 'c Cutting b Kumar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 526,
#      'scorecard': 2506},
#     {'id': 19471,
#      'order': 7,
#      'runs': 2,
#      'balls': 3,
#      'strike_rate': 66.66,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 125,
#      'scorecard': 2506},
#     {'id': 19473,
#      'order': 8,
#      'runs': 3,
#      'balls': 3,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 829,
#      'scorecard': 2506}],
#    'bowlers': [],
#    'is_declared': True,
#    'wicket': 6,
#    'run': 159,
#    'extra': 4,
#    'bye': 0,
#    'leg_bye': 3,
#    'wide': 1,
#    'no_ball': 0,
#    'over': 18.4,
#    'run_rate': 8.51,
#    'required_run_rate': None,
#    'first_batting': True,
#    'team': 53,
#    'match': 1253}],
#  'name': 'mumbai-indians-vs-sunrisers-hyderabad-10th-match-indian-premier-league-2017',
#  'slug': 'mumbai-indians-vs-sunrisers-hyderabad-10th-match-indian-premier-league-2017',
#  'match_summary_text': 'Mum Indians won by 4 wickets (with 8 balls remaining)',
#  'match_date': '10th match (N), Indian Premier League at Mumbai, Apr 12 2017',
#  'is_match_drawn': False,
#  'is_match_abandoned': False,
#  'start_date': '2017-04-12T00:00:00Z',
#  'end_date': '2017-04-12T00:00:00Z',
#  'status': 'completed',
#  'scorecard_json': 'https://win11.neolen.com/media/match/scorecard_json/2020/30/03/03/20/62544370019.json',
#  'espn_id': 1082600,
#  'espn_url': 'https://www.espncricinfo.com/series/8048/scorecard/1082600/mumbai-indians-vs-sunrisers-hyderabad-10th-match-indian-premier-league-2017',
#  'team1': 53,
#  'team2': 58,
#  'toss_winner': 53,
#  'winner': 53,
#  'umpire1': None,
#  'umpire2': None,
#  'referee': None,
#  'venue': 46,
#  'series': None}

# %%
ipl[1]['match_score'][0]['batmens'][1]
# Out:
# {'id': 17340,
#  'order': 2,
#  'runs': 39,
#  'balls': 35,
#  'strike_rate': 111.42,
#  'fours': 3,
#  'sixes': 1,
#  'how_out': 'b Chawla',
#  'fall_of_wicket': None,
#  'fall_of_wicket_over': None,
#  'player': 90,
#  'scorecard': 2227}

# %%
ipl[1]['match_score'][1]['batmens'][1]
# Out:
# {'id': 17345,
#  'order': 2,
#  'runs': 68,
#  'balls': 47,
#  'strike_rate': 144.68,
#  'fours': 8,
#  'sixes': 3,
#  'how_out': 'lbw b Rashid Khan',
#  'fall_of_wicket': None,
#  'fall_of_wicket_over': None,
#  'player': 1517,
#  'scorecard': 2228}

# %%
def findPlayer(id):
    for x in playersDetail:
        if x['id'] == id:
#             print(json.dumps(x, indent=4))
            return x

def batsmenInMatch(ipl,match_id=0):
    batsmen = []
    for i in range(2):
        teams = ipl[match_id]['match_score']
        if len(teams) != 0:
            if len(teams[i]['batmens'])!=0:
                 for x in  teams[i]["batmens"]:
            #         print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))
                      batsmen.append((x['player'],findPlayer(x['player'])['name']))
            else:
                print('{} --> match-{}'.format(ipl[match_id]['match_summary_text'],match_id))
                break

        else:
                print('{} --> match-{}'.format(ipl[match_id]['match_summary_text'],match_id))
                break
                
    return batsmen

def bowlersInMatch(ipl,match_id=0):
    bowlers = []
    for i in range(2):
        teams = ipl[match_id]['match_score']
        if len(teams) != 0:
            if len(teams[i]['bowlers'])!=0:
                 for x in  teams[i]["bowlers"]:
            #         print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))
                      bowlers.append((x['player'],findPlayer(x['player'])['name']))
#             else:
#                 print('{} --> match-{}'.format(ipl[match_id]['match_summary_text'],match_id))

#         else:
#                 print('{} --> match-{}'.format(ipl[match_id]['match_summary_text'],match_id))
    return bowlers

# %%
# def batsmenInMatch(ipl,match_id=0):
#     batsmen = []
#     for i in range(2):
#         try:
#             for x in  ipl[match_id]["match_score"][i]["batmens"]:
#         #         print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))
#                   batsmen.append((x['player'],findPlayer(x['player'])['name']))
#         except IndexError:
#             print("error----------{}".format(x[match_id]))
#             pass
#     return batsmen

# %%
def playersInMatch(ipl,match_id=0):
    players = []
    players.append(batsmenInMatch(ipl,match_id))
    players.append(bowlersInMatch(ipl,match_id))
    return players

# %%
bat = playersInMatch(ipl,0)[0]
bat
# Out:
# [(121, 'V Kohli'),
#  (1332, 'PA Patel'),
#  (87, 'MM Ali'),
#  (208, 'AB de Villiers'),
#  (271, 'SO Hetmyer'),
#  (349, 'S Dube'),
#  (158, 'C de Grandhomme'),
#  (358, 'NA Saini'),
#  (346, 'YS Chahal'),
#  (137, 'UT Yadav'),
#  (354, 'Mohammed Siraj'),
#  (806, 'SR Watson'),
#  (357, 'AT Rayudu'),
#  (356, 'SK Raina'),
#  (351, 'KM Jadhav'),
#  (119, 'RA Jadeja')]

# %%
bow = playersInMatch(ipl,0)[1]
bow
# Out:
# [(347, 'DL Chahar'),
#  (829, 'Harbhajan Singh'),
#  (356, 'SK Raina'),
#  (390, 'Imran Tahir'),
#  (119, 'RA Jadeja'),
#  (555, 'DJ Bravo'),
#  (347, 'DL Chahar'),
#  (829, 'Harbhajan Singh'),
#  (356, 'SK Raina'),
#  (390, 'Imran Tahir'),
#  (119, 'RA Jadeja'),
#  (555, 'DJ Bravo')]

# %%
len(bow)+len(bat)
# Out:
# 28

# %%
#batsmen
def mappingBatsmenToMatch(ipl):
    playerStatPerMatch = {}
    for i,x in enumerate(ipl):
        players = playersInMatch(ipl,i)
        for j in players[0]:
            playerStatPerMatch.setdefault(j[1],list())
            playerStatPerMatch[j[1]].append(x["id"])
    ans = 0
    for x,y in list(playerStatPerMatch.items()):
        print(x,len(y))
    return playerStatPerMatch

# %%
#bowlers
def mappingBowlersToMatch(ipl):
    playerStatPerMatch = {}
    for i,x in enumerate(ipl):
        players = playersInMatch(ipl,i)
        for j in players[1]:
            playerStatPerMatch.setdefault(j[1],list())
            playerStatPerMatch[j[1]].append(x["id"])
    ans = 0
    for x,y in list(playerStatPerMatch.items()):
        print(x,len(y))
    return playerStatPerMatch

# %%
#no of match played in every year
year = ['2019','2018','2017','2016','2015','2014','2013','2012','2011','2010','2009','2008']
cnt=0
a=0 
b=0
for y in year:
    print('{} -----------------------'.format(y))
    print(cnt)
    b=cnt
    for x in ipl:
        if x['name'].find(y) == -1:
                a+=1 
        else:
            cnt+=1
    print(cnt)
    print("No of match played in {} is {}".format(y,cnt-b))
    print('--------------------------------')
    print()
# Out:
# 2019 -----------------------
# 0
# 60
# No of match played in 2019 is 60
# --------------------------------
#
# 2018 -----------------------
# 60
# 120
# No of match played in 2018 is 60
# --------------------------------
#
# 2017 -----------------------
# 120
# 180
# No of match played in 2017 is 60
# --------------------------------
#
# 2016 -----------------------
# 180
# 238
# No of match played in 2016 is 58
# --------------------------------
#
# 2015 -----------------------
# 238
# 296
# No of match played in 2015 is 58
# --------------------------------
#
# 2014 -----------------------
# 296
# 356
# No of match played in 2014 is 60
# --------------------------------
#
# 2013 -----------------------
# 356
# 430
# No of match played in 2013 is 74
# --------------------------------
#
# 2012 -----------------------
# 430
# 506
# No of match played in 2012 is 76
# --------------------------------
#
# 2011 -----------------------
# 506
# 580
# No of match played in 2011 is 74
# --------------------------------
#
# 2010 -----------------------
# 580
# 580
# No of match played in 2010 is 0
# --------------------------------
#
# 2009 -----------------------
# 580
# 639
# No of match played in 2009 is 59
# --------------------------------
#
# 2008 -----------------------
# 639
# 639
# No of match played in 2008 is 0
# JDP Oram 9
# ND Doshi 1
# CK Langeveldt 1
# PA Patel (c) 1
# Y Gnaneswara Rao 1
# ST Jayasuriya 12
# ML Hayden 12
# A Flintoff 3
# T Thushara 2
# NK Patel 2
# T Henderson 2
# Kamran Khan 1
# K Goel 9
# T Kohli 2
# BB McCullum (c) 4
# A Chopra 1
# R Bishnoi 3
# A Kumble 7
# FH Edwards 2
# RJ Quiney 7
# SB Bangar 1
# Yashpal Singh 4
# Pankaj Singh 2
# WA Mota 6
# AA Bilakhia 6
# AN Ghosh 2
# MN van Wyk 5
# Shoaib Ahmed 3
# GR Napier 1
# KP Appanna 1
# SM Katich 9
# TM Srivastava 1
# LA Carseldine 5
# SM Harwood 2
# S Tyagi 2
# W Jaffer 2
# RR Raje 2
# D du Preez 1
# L Ronchi 1
# WPUJC Vaas 2
# C Nanda 1
# MF Maharoof 2
# Mashrafe Mortaza 1
# Jaskaran Singh 1
# SS Shaikh 1
# Mohammad Ashraful 1

# %%
bowl_08_19 = mappingBowlersToMatch(ipl)
# Out:
# Kings XI won by 7 wickets (with 18 balls remaining) --> match-179
# Match abandoned without a ball bowled --> match-190
#  --> match-262
#  --> match-266
# Match abandoned without a ball bowled --> match-461
# No result (abandoned with a toss) --> match-463
# Match abandoned without a ball bowled --> match-525
# No result --> match-573
# Match abandoned without a ball bowled --> match-586
# Match abandoned without a ball bowled --> match-592
# DL Chahar 34
# Harbhajan Singh 139
# SK Raina 54
# Imran Tahir 55
# RA Jadeja 139
# DJ Bravo 112
# YS Chahal 82
# NA Saini 13
# MM Ali 14
# UT Yadav 109
# Mohammed Siraj 26
# S Dube 2
# M Prasidh Krishna 18
# PP Chawla 127
# LH Ferguson 9
# SP Narine 108
# Kuldeep Yadav 39
# AD Russell 61
# N Rana 12
# B Kumar 113
# Shakib Al Hasan 62
# Sandeep Sharma 78
# S Kaul 45
# Rashid Khan 45
# Rasikh Salam 1
# MJ McClenaghan 55
# JJ Bumrah 76
# HH Pandya 60
# KH Pandya 52
# BCJ Cutting 16
# TA Boult 33
# I Sharma 68
# K Rabada 18
# R Tewatia 18
# KMA Paul 8
# AR Patel 80
# DS Kulkarni 78
# K Gowtham 22
# JC Archer 21
# BA Stokes 30
# JD Unadkat 69
# S Gopal 30
# SM Curran 9
# Mujeeb Ur Rahman 16
# Mohammed Shami 49
# R Ashwin 123
# AS Rajpoot 23
# SN Thakur 35
# A Mishra 124
# CV Varun 1
# GC Viljoen 6
# AJ Tye 26
# Mandeep Singh 2
# C de Grandhomme 19
# SL Malinga 109
# M Markande 17
# S Nadeem 59
# V Shankar 10
# M Ashwin 22
# S Lamichhane 9
# CH Morris 60
# HV Patel 41
# P Ray Barman 1
# Mohammad Nabi 13
# MJ Santner 4
# Avesh Khan 8
# GH Vihari 6
# VR Aaron 45
# STR Binny 60
# MP Stoinis 23
# MM Sharma 83
# JP Behrendorff 5
# RD Chahar 15
# TG Southee 38
# P Negi 40
# SC Kuggeleijn 2
# YK Pathan 57
# AS Joseph 3
# Y Venugopal Rao 12
# R Rampaul 12
# RG Sharma 20
# SA Yadav 1
# R Shukla 7
# KK Cooper 25
# LMP Simmons 1
# S Rana 3
# DJ Hussey 16
# K Santokie 2
# VS Malik 10
# B Lee 29
# JDP Oram 10
# CL White 4
# S Sreesanth 23
# SK Trivedi 50
# DP Nannes 20
# RJ Harris 29
# TM Dilshan 20
# SW Tait 13
# BMAJ Mendis 2
# R McLaren 8
# Harmeet Singh 20
# Anand Rajan 8
# AJ Finch 4
# J Syed Mohammad 11
# SMSM Senanayake 8
# A Chandila 12
# AM Nayar 13
# AB McDonald 6
# AA Chavan 13
# V Sehwag 5
# AB Agarkar 26
# AD Mascarenhas 10
# RE van der Merwe 20
# BAW Mendis 7
# LJ Wright 5
# AG Murtaza 9
# BA Bhatt 15
# TL Suman 9
# S Narwal 1
# K Upadhyay 3
# MG Neser 1
# BJ Rohrer 1
# A Mithun 15
# RV Gomez 9
# BJ Hodge 16
# AC Gilchrist 1
# JEC Franklin 15
# DE Bollinger 19
# PC Valthaty 10
# A Singh 23
# DAJ Bracewell 1
# DL Vettori 29
# DJ Harris 2
# TP Sudhindra 3
# F du Plessis 1
# JD Ryder 16
# KP Pietersen 7
# RR Bhatkal 1
# AL Menaria 12
# KMDN Kulasekara 5
# VY Mahesh 5
# Pankaj Singh 10
# CJ McKay 2
# KP Appanna 11
# V Pratap Singh 9
# Y Nagar 7
# AC Thomas 15
# SC Ganguly 10
# RJ Peterson 4
# S Dhawan 6
# AUK Pathan 3
# MJ Clarke 5
# AA Jhunjhunwala 5
# P Parameswaran 8
# SPD Smith 1
# RR Powar 14
# Sunny Gupta 1
# S Randiv 8
# SK Warne 25
# SB Wagh 7
# M Manhas 3
# NJ Rimmington 1
# DB Ravi Teja 1
# SB Styris 3
# JJ van der Wath 3
# R Ninan 2
# ND Doshi 3
# JR Hopes 9
# AS Raut 5
# Joginder Sharma 5
# SJ Srivastava 6
# NL McCullum 2
# JE Taylor 5
# Kamran Khan 6
# B Akhil 6
# A Symonds 11
# AM Salvi 7
# I Malhotra 1
# B Chipli 1
# L Ablish 1
# CK Langeveldt 4
# AA Kazi 1
# LRPL Taylor 2
# S Sriram 1
# P Prasanth 1
# Y Gnaneswara Rao 1
# SS Mundhe 1
# RW Price 1
# T Thushara 2
# A Flintoff 3
# RR Raje 4
# ST Jayasuriya 9
# T Henderson 2
# A Kumble 16
# YA Abdulla 9
# VRV Singh 4
# FH Edwards 6
# RR Bose 1
# Shoaib Ahmed 7
# SR Tendulkar 4
# K Goel 4
# WA Mota 5
# S Tyagi 8
# GR Napier 1
# SM Harwood 3
# D du Preez 2
# LA Carseldine 1
# C Nanda 3
# SS Sarkar 2
# WPUJC Vaas 2
# AM Rahane 1
# MF Maharoof 3
# Mashrafe Mortaza 1
# RA Shaikh 1
# Jaskaran Singh 1

# %%
#No of player in bat and bowl in ipl
print(len(bat_08_19.keys()),len(bowl_08_19.keys()))
# Out:
# 463 361

# %%
# ipl[1]['name'].find('2019')
