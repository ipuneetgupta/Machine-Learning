# %%
import json
import requests
def extractData(url):
    payload = {}
    headers= {}
    response = requests.request("GET", url, headers=headers, data = payload)
    return response.text

# %%
data = json.loads(extractData("https://win11.neolen.com/api/match-full"))
type(data)
# Out:
# list

# %%
# print(json.dumps(data, indent=4))

# %%
ipl = list()
for x in data[477:]:
  ipl.append(x)
len(ipl)
# Out:
# 639

# %%
ipl[62
   ]
# Out:
# {'id': 1178,
#  'match_score': [{'id': 2355,
#    'batmens': [{'id': 18311,
#      'order': 1,
#      'runs': 43,
#      'balls': 27,
#      'strike_rate': 159.25,
#      'fours': 6,
#      'sixes': 2,
#      'how_out': 'b Narine',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1322,
#      'scorecard': 2355},
#     {'id': 18312,
#      'order': 2,
#      'runs': 4,
#      'balls': 4,
#      'strike_rate': 100.0,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'c Vinay Kumar b Chawla',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 207,
#      'scorecard': 2355},
#     {'id': 18313,
#      'order': 3,
#      'runs': 31,
#      'balls': 33,
#      'strike_rate': 93.93,
#      'fours': 1,
#      'sixes': 1,
#      'how_out': 'b Rana',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 121,
#      'scorecard': 2355},
#     {'id': 18314,
#      'order': 4,
#      'runs': 44,
#      'balls': 23,
#      'strike_rate': 191.3,
#      'fours': 1,
#      'sixes': 5,
#      'how_out': 'c Johnson b Rana',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 208,
#      'scorecard': 2355},
#     {'id': 18315,
#      'order': 5,
#      'runs': 6,
#      'balls': 10,
#      'strike_rate': 60.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'c Singh b Johnson',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1462,
#      'scorecard': 2355},
#     {'id': 18316,
#      'order': 6,
#      'runs': 37,
#      'balls': 18,
#      'strike_rate': 205.55,
#      'fours': 4,
#      'sixes': 2,
#      'how_out': 'c Kuldeep Yadav b Vinay Kumar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 865,
#      'scorecard': 2355},
#     {'id': 18317,
#      'order': 7,
#      'runs': 5,
#      'balls': 5,
#      'strike_rate': 100.0,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'c Russell b Vinay Kumar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 113,
#      'scorecard': 2355},
#     {'id': 18318,
#      'order': 8,
#      'runs': 0,
#      'balls': 0,
#      'strike_rate': 0.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 530,
#      'scorecard': 2355}],
#    'bowlers': [{'id': 12881,
#      'order': 1,
#      'run_conceded': 30,
#      'maidens': 0,
#      'wickets': 2,
#      'overs': 2.0,
#      'economy': 15.0,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 3,
#      'sixes': 3,
#      'zeros': 6,
#      'player': 993,
#      'scorecard': 2355},
#     {'id': 12882,
#      'order': 2,
#      'run_conceded': 31,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 7.75,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 2,
#      'sixes': 2,
#      'zeros': 10,
#      'player': 1449,
#      'scorecard': 2355},
#     {'id': 12883,
#      'order': 3,
#      'run_conceded': 33,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 3.0,
#      'economy': 11.0,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 1,
#      'sixes': 2,
#      'zeros': 4,
#      'player': 122,
#      'scorecard': 2355},
#     {'id': 12884,
#      'order': 4,
#      'run_conceded': 30,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 7.5,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 3,
#      'sixes': 1,
#      'zeros': 9,
#      'player': 559,
#      'scorecard': 2355},
#     {'id': 12885,
#      'order': 5,
#      'run_conceded': 30,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 7.5,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 4,
#      'sixes': 1,
#      'zeros': 12,
#      'player': 991,
#      'scorecard': 2355},
#     {'id': 12886,
#      'order': 6,
#      'run_conceded': 10,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 2.0,
#      'economy': 5.0,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 0,
#      'sixes': 0,
#      'zeros': 2,
#      'player': 436,
#      'scorecard': 2355},
#     {'id': 12887,
#      'order': 7,
#      'run_conceded': 11,
#      'maidens': 0,
#      'wickets': 2,
#      'overs': 1.0,
#      'economy': 11.0,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 1,
#      'sixes': 1,
#      'zeros': 3,
#      'player': 1517,
#      'scorecard': 2355}],
#    'is_declared': True,
#    'wicket': 7,
#    'run': 176,
#    'extra': 6,
#    'bye': 0,
#    'leg_bye': 1,
#    'wide': 5,
#    'no_ball': 0,
#    'over': 20.0,
#    'run_rate': 8.8,
#    'required_run_rate': None,
#    'first_batting': True,
#    'team': 57,
#    'match': 1178},
#   {'id': 2356,
#    'batmens': [{'id': 18319,
#      'order': 1,
#      'runs': 50,
#      'balls': 19,
#      'strike_rate': 263.15,
#      'fours': 4,
#      'sixes': 5,
#      'how_out': 'b Yadav',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 559,
#      'scorecard': 2356},
#     {'id': 18320,
#      'order': 2,
#      'runs': 5,
#      'balls': 8,
#      'strike_rate': 62.5,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'c de Villiers b Woakes',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 316,
#      'scorecard': 2356},
#     {'id': 18321,
#      'order': 3,
#      'runs': 13,
#      'balls': 12,
#      'strike_rate': 108.33,
#      'fours': 0,
#      'sixes': 1,
#      'how_out': 'c McCullum b Yadav',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1527,
#      'scorecard': 2356},
#     {'id': 18322,
#      'order': 4,
#      'runs': 34,
#      'balls': 25,
#      'strike_rate': 136.0,
#      'fours': 2,
#      'sixes': 2,
#      'how_out': 'lbw b Washington Sundar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1517,
#      'scorecard': 2356},
#     {'id': 18323,
#      'order': 5,
#      'runs': 35,
#      'balls': 29,
#      'strike_rate': 120.68,
#      'fours': 4,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1626,
#      'scorecard': 2356},
#     {'id': 18324,
#      'order': 6,
#      'runs': 6,
#      'balls': 6,
#      'strike_rate': 100.0,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'c †de Kock b Woakes',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1525,
#      'scorecard': 2356},
#     {'id': 18325,
#      'order': 7,
#      'runs': 15,
#      'balls': 11,
#      'strike_rate': 136.36,
#      'fours': 2,
#      'sixes': 1,
#      'how_out': 'c de Villiers b Woakes',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 436,
#      'scorecard': 2356},
#     {'id': 18326,
#      'order': 8,
#      'runs': 6,
#      'balls': 3,
#      'strike_rate': 200.0,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 993,
#      'scorecard': 2356}],
#    'bowlers': [{'id': 12888,
#      'order': 1,
#      'run_conceded': 29,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 3.0,
#      'economy': 9.66,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 3,
#      'sixes': 1,
#      'zeros': 6,
#      'player': 346,
#      'scorecard': 2356},
#     {'id': 12889,
#      'order': 2,
#      'run_conceded': 36,
#      'maidens': 0,
#      'wickets': 3,
#      'overs': 4.0,
#      'economy': 9.0,
#      'wides': 2,
#      'no_balls': 0,
#      'fours': 5,
#      'sixes': 2,
#      'zeros': 15,
#      'player': 113,
#      'scorecard': 2356},
#     {'id': 12890,
#      'order': 3,
#      'run_conceded': 48,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 12.0,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 2,
#      'sixes': 4,
#      'zeros': 4,
#      'player': 530,
#      'scorecard': 2356},
#     {'id': 12891,
#      'order': 4,
#      'run_conceded': 27,
#      'maidens': 0,
#      'wickets': 2,
#      'overs': 4.0,
#      'economy': 6.75,
#      'wides': 2,
#      'no_balls': 0,
#      'fours': 3,
#      'sixes': 1,
#      'zeros': 13,
#      'player': 137,
#      'scorecard': 2356},
#     {'id': 12892,
#      'order': 5,
#      'run_conceded': 34,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 3.5,
#      'economy': 8.86,
#      'wides': 4,
#      'no_balls': 0,
#      'fours': 2,
#      'sixes': 1,
#      'zeros': 6,
#      'player': 1611,
#      'scorecard': 2356}],
#    'is_declared': True,
#    'wicket': 6,
#    'run': 177,
#    'extra': 13,
#    'bye': 0,
#    'leg_bye': 3,
#    'wide': 10,
#    'no_ball': 0,
#    'over': 18.5,
#    'run_rate': 9.39,
#    'required_run_rate': None,
#    'first_batting': True,
#    'team': 52,
#    'match': 1178}],
#  'name': 'kolkata-knight-riders-vs-royal-challengers-bangalore-3rd-match-indian-premier-league-2018',
#  'slug': 'kolkata-knight-riders-vs-royal-challengers-bangalore-3rd-match-indian-premier-league-2018',
#  'match_summary_text': 'KKR won by 4 wickets (with 7 balls remaining)',
#  'match_date': '3rd match (N), Indian Premier League at Kolkata, Apr 8 2018',
#  'is_match_drawn': False,
#  'is_match_abandoned': False,
#  'start_date': '2018-04-08T00:00:00Z',
#  'end_date': '2018-04-08T00:00:00Z',
#  'status': 'completed',
#  'scorecard_json': 'https://win11.neolen.com/media/match/scorecard_json/2020/06/03/03/20/38269017738.json',
#  'espn_id': 1136563,
#  'espn_url': 'https://www.espncricinfo.com/series/8048/scorecard/1136563/kolkata-knight-riders-vs-royal-challengers-bangalore-3rd-match-indian-premier-league-2018',
#  'team1': 52,
#  'team2': 57,
#  'toss_winner': 52,
#  'winner': 52,
#  'umpire1': None,
#  'umpire2': None,
#  'referee': None,
#  'venue': 90,
#  'series': None}

# %%
playersDetail = json.loads(extractData("https://win11.neolen.com/api/player-full"))
type(playersDetail)
# Out:
# list

# %%
playersDetail[758]["bowling_statistics"][0]['player']
# Out:
# 926

# %%
# for x in playersDetail[:]:
#         if x['id']==121:
#             print(json.dumps(x, indent=4))

# %%
def findPlayer(id):
    for x in playersDetail:
        if x['id'] == id:
#             print(json.dumps(x, indent=4))
            return x

def batsmenInMatch(ipl,match_id=0):
    batsmen = []
    try:
        for x in  ipl[match_id]["match_score"][0]["batmens"]:
    #         print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))
              batsmen.append((x['player'],findPlayer(x['player'])['name']))
    except IndexError:
        pass
    return batsmen

def bowlersInMatch(ipl,match_id=0):
    bowlers = []
    try:
        for x in  ipl[match_id]["match_score"][0]["bowlers"]:
    #         print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))
              bowlers.append((x['player'],findPlayer(x['player'])['name']))
    except IndexError:
        pass
    return bowlers

# %%
def playersInMatch(ipl,match_id=0):
    players = []
    players.append(batsmenInMatch(ipl,match_id))
    players.append(bowlersInMatch(ipl,match_id))
    return players

# %%
# print(json.dumps(findPlayer(87), indent=4))

# %%
# for x in  ipl[0]["match_score"][0]["batmens"]:
#     print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))

# %%
#  ipl[0]["match_score"][0]["batmens"]

# %%
player = playersInMatch(ipl,191)
len(ipl)
# Out:
# 639

# %%
player[0]
# Out:
# [(423, 'CH Gayle'),
#  (121, 'V Kohli'),
#  (208, 'AB de Villiers'),
#  (806, 'SR Watson')]

# %%
player[1]
# Out:
# [(1431, 'P Kumar'),
#  (867, 'DS Kulkarni'),
#  (1430, 'S Kaushik'),
#  (1434, 'PV Tambe'),
#  (555, 'DJ Bravo'),
#  (119, 'RA Jadeja'),
#  (874, 'DR Smith')]

# %%
playerStatPerMatch = {}
for i,x in enumerate(ipl):
    players = playersInMatch(ipl,i)
    for j in players[0]:
        playerStatPerMatch.setdefault(j[1],list())
        playerStatPerMatch[j[1]].append(x["id"])
ans = 0
for x,y in list(playerStatPerMatch.items()):
    print(x,len(y))
# Out:
# V Kohli 71
# PA Patel 62
# MM Ali 9
# AB de Villiers 65
# SO Hetmyer 2
# S Dube 1
# C de Grandhomme 10
# NA Saini 2
# YS Chahal 5
# UT Yadav 14
# Mohammed Siraj 5
# DA Warner 58
# JM Bairstow 4
# V Shankar 18
# YK Pathan 59
# MK Pandey 46
# PP Shaw 13
# S Dhawan 78
# SS Iyer 31
# CA Ingram 5
# RR Pant 24
# KMA Paul 4
# AR Patel 35
# R Tewatia 7
# KL Rahul 33
# CH Gayle 56
# MA Agarwal 35
# SN Khan 12
# N Pooran 3
# Mandeep Singh 43
# CA Lynn 18
# SP Narine 24
# RV Uthappa 58
# N Rana 19
# AD Russell 24
# KD Karthik (c) 16
# Q de Kock 25
# RG Sharma 83
# SA Yadav 38
# Yuvraj Singh 50
# KA Pollard 68
# KH Pandya 29
# HH Pandya 33
# MJ McClenaghan 12
# M Markande 6
# JJ Bumrah 5
# AM Rahane 66
# JC Buttler 19
# SV Samson 34
# BA Stokes 16
# NS Naik 2
# Shubman Gill 13
# PP Chawla 37
# Kuldeep Yadav 5
# AT Rayudu 60
# SR Watson 52
# SK Raina 85
# KM Jadhav 32
# MS Dhoni (c) 75
# DJ Bravo 40
# RA Jadeja 57
# SM Curran 5
# DA Miller 40
# GC Viljoen 2
# R Ashwin 24
# M Ashwin 2
# Mohammed Shami 8
# Mujeeb Ur Rahman 3
# MP Stoinis 17
# CH Morris 15
# K Rabada 3
# I Sharma 7
# F du Plessis 31
# Ishan Kishan 19
# RD Chahar 3
# AS Joseph 1
# AD Nath 6
# P Negi 18
# TG Southee 7
# SPD Smith 32
# RA Tripathi 16
# Mohammad Nabi 7
# DJ Hooda 21
# M Prasidh Krishna 1
# HF Gurney 1
# KK Nair 30
# R Parag 3
# JC Archer 5
# S Gopal 8
# JL Denly 1
# CR Brathwaite 9
# C Munro 7
# SW Billings 10
# BCJ Cutting 11
# Harpreet Brar 1
# RK Singh 4
# Y Prithvi Raj 1
# KC Cariappa 2
# DW Steyn 20
# AJ Turner 1
# STR Binny 32
# E Lewis 11
# KS Williamson 23
# Shakib Al Hasan 27
# WP Saha 48
# Rashid Khan 11
# B Kumar 21
# S Kaul 4
# SE Rutherford 2
# Abhishek Sharma 4
# H Klaasen 2
# Gurkeerat Singh 16
# AJ Tye 7
# LS Livingstone 1
# MK Lomror 2
# K Gowtham 8
# IS Sodhi 2
# VR Aaron 7
# MJ Guptill 10
# M Vijay 48
# Basil Thampi 6
# A Mishra 23
# TA Boult 1
# G Gambhir 52
# DT Christian 22
# BB McCullum 51
# CR Woakes 5
# Washington Sundar 5
# DJM Short 5
# DS Kulkarni 8
# JD Unadkat 10
# B Laughlin 1
# TK Curran 3
# PJ Sangwan 9
# AJ Finch 38
# MM Sharma 14
# A Dananjaya 1
# Shivam Mavi 2
# MG Johnson 18
# BB Sran 5
# JJ Roy 6
# GJ Maxwell 38
# Sandeep Sharma 7
# CJ Anderson 16
# AD Hales 3
# M Vohra 24
# LE Plunkett 1
# KV Sharma 20
# NV Ojha 41
# JP Duminy 43
# HV Patel 6
# JPR Scantlebury-Searles 2
# AS Rajpoot 3
# Anureet Singh 3
# SP Goswami 11
# MK Tiwary 32
# MC Henriques 34
# LMP Simmons 18
# Harbhajan Singh 38
# R Vinay Kumar 20
# KD Karthik 53
# DR Smith 43
# NM Coulter-Nile 8
# Z Khan 8
# MS Dhoni 8
# R Bhatia 20
# Vishnu Vinod 3
# Iqbal Abdulla 3
# TS Mills 1
# P Kumar 24
# KP Pietersen 13
# MR Marsh 6
# SE Marsh 31
# P Sahu 2
# AP Tare 13
# EJG Morgan 19
# A Ashish Reddy 13
# A Nehra 10
# NLTC Perera 19
# IK Pathan 28
# D Wiese 2
# KJ Abbott 2
# TM Head 7
# KW Richardson 2
# R Dhawan 10
# JA Morkel 33
# Bipul Sharma 8
# JP Faulkner 21
# SS Tiwary 22
# PSP Handscomb 1
# Sachin Baby 4
# J Yadav 1
# HM Amla 8
# UT Khawaja 2
# GJ Bailey 21
# Ankit Sharma 5
# SN Thakur 4
# LH Ferguson 1
# PJ Cummins 4
# AD Mathews 17
# UBT Chand 9
# JO Holder 3
# M Morkel 5
# F Behardien 1
# ER Dwivedi 2
# SB Jakati 6
# S Badree 1
# S Aravind 4
# A Choudhary 1
# AR Bawne 1
# Ankit Soni 3
# S Nadeem 8
# AF Milne 1
# SP Jackson 1
# Swapnil Singh 2
# MN Samuels 6
# MM Patel 3
# CJ Jordan 1
# IR Jaggi 5
# V Sehwag 36
# DJG Sammy 12
# SA Abbott 1
# AN Ahmed 1
# J Suchith 4
# RS Bopara 8
# PV Tambe 1
# Imran Tahir 2
# DJ Muthuswami 1
# GH Vihari 11
# RG More 1
# RN ten Doeschate 10
# J Botha 16
# BE Hendricks 2
# MA Starc 5
# JH Kallis 29
# LRPL Taylor 14
# Y Venugopal Rao 19
# MEK Hussey 29
# SL Malinga 8
# PP Ojha 8
# AM Nayar 15
# M Manhas 13
# BW Hilfenhaus 1
# CA Pujara 9
# CM Gautam 6
# YV Takawale 3
# S Rana 5
# R Rampaul 5
# AB Dinda 5
# L Balaji 7
# WD Parnell 8
# LR Shukla 11
# BR Dunk 1
# Shivam Sharma 2
# R Shukla 2
# VH Zol 2
# DH Yagnik 12
# KK Cooper 8
# DJ Hussey 23
# M de Lange 1
# RR Rossouw 1
# S Anirudha 6
# Parvez Rasool 2
# JDS Neesham 1
# BJ Hodge 30
# DPMD Jayawardene 21
# MC Juneja 4
# TM Dilshan 16
# KB Arun Karthik 3
# PA Reddy 5
# KC Sangakkara 17
# CL White 20
# DB Ravi Teja 12
# MDKJ Perera 2
# R Dravid 26
# AL Menaria 15
# S Sreesanth 5
# RT Ponting 3
# SR Tendulkar 29
# TL Suman 11
# R Sharma 6
# M Kartik 7
# BB Samantray 6
# AC Gilchrist (c) 26
# Azhar Mahmood 12
# R Sathish 6
# RJ Harris 8
# P Awana 5
# MS Bisla 6
# R McLaren 3
# MS Gony 7
# BJ Rohrer 2
# PC Valthaty 12
# AD Mascarenhas 4
# DB Das 6
# SMSM Senanayake 1
# A Chandila 2
# SW Tait 3
# SK Trivedi 2
# LJ Wright 3
# RE van der Merwe 8
# AB Agarkar 6
# X Thalaivan Sargunam 1
# KC Sangakkara (c) 10
# A Mukund 1
# S Badrinath 25
# OA Shah 10
# BMAJ Mendis 1
# M Rawat 1
# A Mithun 3
# RV Gomez 8
# P Dogra 3
# DE Bollinger 1
# B Lee 6
# SC Ganguly 15
# CJ Ferguson 4
# AB McDonald 3
# DL Vettori 6
# JD Ryder 14
# B Chipli 11
# RE Levi 2
# JEC Franklin 5
# RR Bhatkal 1
# Harmeet Singh 1
# BA Bhatt 1
# DJ Jacobs 5
# CJ McKay 1
# RP Singh 7
# AA Jhunjhunwala 1
# N Saini 5
# Y Nagar 9
# V Pratap Singh 1
# AA Chavan 2
# AUK Pathan 3
# RJ Peterson 1
# DJ Harris 2
# MJ Clarke 1
# AP Majumdar 1
# SD Chitnis 4
# HH Gibbs 8
# GB Hogg 1
# SB Styris 2
# VVS Laxman 5
# Sunny Singh 2
# NJ Rimmington 1
# S Sohal 8
# AG Paunikar 2
# GC Smith 5
# MD Mishra 3
# FY Fazal 2
# AS Raut 5
# SK Warne 6
# A Singh 2
# TD Paine 1
# SB Wagh 1
# AC Thomas 1
# RR Powar 3
# BJ Haddin 1
# A Symonds 9
# M Muralitharan 4
# JR Hopes 1
# MS Wade 2
# JE Taylor 1
# AG Murtaza 1
# M Kaif 2
# TR Birt 2
# Harpreet Singh 1
# NL McCullum 1
# MV Boucher 5
# AC Blizzard 2
# M Klinger 2
# I Malhotra 1
# P Parameswaran 1
# SJ Srivastava 2
# MJ Lumb 1
# PR Shah 4
# JDP Oram 7
# ND Doshi 1
# LA Pomersbach 4
# ST Jayasuriya 7
# B Akhil 2
# K Goel 5
# T Kohli 2
# BB McCullum (c) 1
# A Chopra 1
# ML Hayden 8
# A Flintoff 1
# FH Edwards 2
# RJ Quiney 3
# Pankaj Singh 2
# A Kumble 3
# WA Mota 4
# MN van Wyk 4
# AA Bilakhia 3
# Shoaib Ahmed 1
# GR Napier 1
# R Bishnoi 1
# KP Appanna 1
# S Tyagi 2
# LA Carseldine 2
# W Jaffer 1
# D du Preez 1
# L Ronchi 1
# RR Raje 1
# SA Asnodkar 2
# SM Harwood 1
# Yashpal Singh 1
# WPUJC Vaas 1
# AN Ghosh 1
# SM Katich 2
# MF Maharoof 2
# Mashrafe Mortaza 1
# NK Patel 1
# T Henderson 1
# T Thushara 1
# Mohammad Ashraful 1

# %%
# oak = {'a': 1}
# oak.setdefault('b',list())
# oak.setdefault('b',list())

# oak
#     for j in batsmen[0]:
#         playerStatPerMatch.setdefault(j[1],list())
#         playerStatPerMatch[j[1]].append(x["id"])

# %%
for i in range(100):
    player = playersInMatch(ipl,i)
