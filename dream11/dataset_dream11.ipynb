# %%
import json
import requests
def extractData(url):
    payload = {}
    headers= {}
    response = requests.request("GET", url, headers=headers, data = payload)
    return response.text

# %%
data = json.loads(extractData("https://win11.neolen.com/api/match-full"))
type(data)
# Out:
# list

# %%
# print(json.dumps(data, indent=4))

# %%
ipl = list()
for x in data[477:]:
  ipl.append(x)
len(ipl)
# Out:
# 639

# %%
ipl[59]
# Out:
# {'id': 1175,
#  'match_score': [{'id': 2349,
#    'batmens': [{'id': 18262,
#      'order': 1,
#      'runs': 29,
#      'balls': 17,
#      'strike_rate': 170.58,
#      'fours': 0,
#      'sixes': 4,
#      'how_out': 'c †Dhoni b Thakur',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 207,
#      'scorecard': 2349},
#     {'id': 18263,
#      'order': 2,
#      'runs': 15,
#      'balls': 14,
#      'strike_rate': 107.14,
#      'fours': 1,
#      'sixes': 1,
#      'how_out': 'c †Dhoni b Chahar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 132,
#      'scorecard': 2349},
#     {'id': 18264,
#      'order': 3,
#      'runs': 15,
#      'balls': 17,
#      'strike_rate': 88.23,
#      'fours': 1,
#      'sixes': 0,
#      'how_out': 'b Imran Tahir',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1529,
#      'scorecard': 2349},
#     {'id': 18265,
#      'order': 4,
#      'runs': 23,
#      'balls': 26,
#      'strike_rate': 88.46,
#      'fours': 3,
#      'sixes': 0,
#      'how_out': 'c Raina b Imran Tahir',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1429,
#      'scorecard': 2349},
#     {'id': 18266,
#      'order': 5,
#      'runs': 7,
#      'balls': 7,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'c & b Thakur',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 526,
#      'scorecard': 2349},
#     {'id': 18267,
#      'order': 6,
#      'runs': 41,
#      'balls': 25,
#      'strike_rate': 164.0,
#      'fours': 3,
#      'sixes': 3,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 432,
#      'scorecard': 2349},
#     {'id': 18268,
#      'order': 7,
#      'runs': 16,
#      'balls': 10,
#      'strike_rate': 160.0,
#      'fours': 1,
#      'sixes': 1,
#      'how_out': 'lbw b Chahar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 125,
#      'scorecard': 2349},
#     {'id': 18269,
#      'order': 8,
#      'runs': 0,
#      'balls': 2,
#      'strike_rate': 0.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'c du Plessis b Chahar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 524,
#      'scorecard': 2349},
#     {'id': 18270,
#      'order': 9,
#      'runs': 0,
#      'balls': 2,
#      'strike_rate': 0.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'run out (du Plessis/Bravo)',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 719,
#      'scorecard': 2349},
#     {'id': 18271,
#      'order': 10,
#      'runs': 0,
#      'balls': 0,
#      'strike_rate': 0.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 117,
#      'scorecard': 2349}],
#    'bowlers': [{'id': 12845,
#      'order': 1,
#      'run_conceded': 26,
#      'maidens': 1,
#      'wickets': 3,
#      'overs': 4.0,
#      'economy': 6.5,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 1,
#      'sixes': 3,
#      'zeros': 17,
#      'player': 347,
#      'scorecard': 2349},
#     {'id': 12846,
#      'order': 2,
#      'run_conceded': 37,
#      'maidens': 0,
#      'wickets': 2,
#      'overs': 4.0,
#      'economy': 9.25,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 0,
#      'sixes': 4,
#      'zeros': 10,
#      'player': 134,
#      'scorecard': 2349},
#     {'id': 12847,
#      'order': 3,
#      'run_conceded': 27,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 4.0,
#      'economy': 6.75,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 3,
#      'sixes': 0,
#      'zeros': 7,
#      'player': 829,
#      'scorecard': 2349},
#     {'id': 12848,
#      'order': 4,
#      'run_conceded': 24,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 3.0,
#      'economy': 8.0,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 4,
#      'sixes': 0,
#      'zeros': 7,
#      'player': 555,
#      'scorecard': 2349},
#     {'id': 12849,
#      'order': 5,
#      'run_conceded': 23,
#      'maidens': 0,
#      'wickets': 2,
#      'overs': 3.0,
#      'economy': 7.66,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 0,
#      'sixes': 2,
#      'zeros': 7,
#      'player': 390,
#      'scorecard': 2349},
#     {'id': 12850,
#      'order': 6,
#      'run_conceded': 12,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 2.0,
#      'economy': 6.0,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 1,
#      'sixes': 0,
#      'zeros': 3,
#      'player': 119,
#      'scorecard': 2349}],
#    'is_declared': True,
#    'wicket': 8,
#    'run': 149,
#    'extra': 3,
#    'bye': 0,
#    'leg_bye': 0,
#    'wide': 3,
#    'no_ball': 0,
#    'over': 20.0,
#    'run_rate': 7.45,
#    'required_run_rate': None,
#    'first_batting': True,
#    'team': 53,
#    'match': 1175},
#   {'id': 2350,
#    'batmens': [{'id': 18272,
#      'order': 1,
#      'runs': 26,
#      'balls': 13,
#      'strike_rate': 200.0,
#      'fours': 3,
#      'sixes': 1,
#      'how_out': 'st †de Kock b KH Pandya',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 209,
#      'scorecard': 2350},
#     {'id': 18273,
#      'order': 2,
#      'runs': 80,
#      'balls': 59,
#      'strike_rate': 135.59,
#      'fours': 8,
#      'sixes': 4,
#      'how_out': 'run out (KH Pandya/†de Kock)',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 806,
#      'scorecard': 2350},
#     {'id': 18274,
#      'order': 3,
#      'runs': 8,
#      'balls': 14,
#      'strike_rate': 57.14,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'lbw b Chahar',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 356,
#      'scorecard': 2350},
#     {'id': 18275,
#      'order': 4,
#      'runs': 1,
#      'balls': 4,
#      'strike_rate': 25.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'c †de Kock b Bumrah',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 357,
#      'scorecard': 2350},
#     {'id': 18276,
#      'order': 5,
#      'runs': 2,
#      'balls': 8,
#      'strike_rate': 25.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'run out (Ishan Kishan)',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 1238,
#      'scorecard': 2350},
#     {'id': 18277,
#      'order': 6,
#      'runs': 15,
#      'balls': 15,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 1,
#      'how_out': 'c †de Kock b Bumrah',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 555,
#      'scorecard': 2350},
#     {'id': 18278,
#      'order': 7,
#      'runs': 5,
#      'balls': 5,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'not out',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 119,
#      'scorecard': 2350},
#     {'id': 18279,
#      'order': 8,
#      'runs': 2,
#      'balls': 2,
#      'strike_rate': 100.0,
#      'fours': 0,
#      'sixes': 0,
#      'how_out': 'lbw b Malinga',
#      'fall_of_wicket': None,
#      'fall_of_wicket_over': None,
#      'player': 134,
#      'scorecard': 2350}],
#    'bowlers': [{'id': 12851,
#      'order': 1,
#      'run_conceded': 24,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 4.0,
#      'economy': 6.0,
#      'wides': 2,
#      'no_balls': 0,
#      'fours': 2,
#      'sixes': 0,
#      'zeros': 12,
#      'player': 719,
#      'scorecard': 2350},
#     {'id': 12852,
#      'order': 2,
#      'run_conceded': 39,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 3.0,
#      'economy': 13.0,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 3,
#      'sixes': 4,
#      'zeros': 8,
#      'player': 526,
#      'scorecard': 2350},
#     {'id': 12853,
#      'order': 3,
#      'run_conceded': 49,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 12.25,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 5,
#      'sixes': 2,
#      'zeros': 7,
#      'player': 406,
#      'scorecard': 2350},
#     {'id': 12854,
#      'order': 4,
#      'run_conceded': 14,
#      'maidens': 0,
#      'wickets': 2,
#      'overs': 4.0,
#      'economy': 3.5,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 0,
#      'sixes': 0,
#      'zeros': 13,
#      'player': 117,
#      'scorecard': 2350},
#     {'id': 12855,
#      'order': 5,
#      'run_conceded': 14,
#      'maidens': 0,
#      'wickets': 1,
#      'overs': 4.0,
#      'economy': 3.5,
#      'wides': 0,
#      'no_balls': 0,
#      'fours': 1,
#      'sixes': 0,
#      'zeros': 13,
#      'player': 524,
#      'scorecard': 2350},
#     {'id': 12856,
#      'order': 6,
#      'run_conceded': 3,
#      'maidens': 0,
#      'wickets': 0,
#      'overs': 1.0,
#      'economy': 3.0,
#      'wides': 1,
#      'no_balls': 0,
#      'fours': 0,
#      'sixes': 0,
#      'zeros': 4,
#      'player': 125,
#      'scorecard': 2350}],
#    'is_declared': True,
#    'wicket': 7,
#    'run': 148,
#    'extra': 9,
#    'bye': 5,
#    'leg_bye': 0,
#    'wide': 4,
#    'no_ball': 0,
#    'over': 20.0,
#    'run_rate': 7.4,
#    'required_run_rate': None,
#    'first_batting': True,
#    'team': 46,
#    'match': 1175}],
#  'name': 'mumbai-indians-vs-chennai-super-kings-final-indian-premier-league-2019',
#  'slug': 'mumbai-indians-vs-chennai-super-kings-final-indian-premier-league-2019',
#  'match_summary_text': 'Mum Indians won by 1 run',
#  'match_date': 'Final (N), Indian Premier League at Hyderabad (Deccan), May 12 2019',
#  'is_match_drawn': False,
#  'is_match_abandoned': False,
#  'start_date': '2019-05-12T00:00:00Z',
#  'end_date': '2019-05-12T00:00:00Z',
#  'status': 'completed',
#  'scorecard_json': 'https://win11.neolen.com/media/match/scorecard_json/2020/02/03/03/20/30616465568.json',
#  'espn_id': 1181768,
#  'espn_url': 'https://www.espncricinfo.com/series/8048/scorecard/1181768/mumbai-indians-vs-chennai-super-kings-final-indian-premier-league-2019',
#  'team1': 53,
#  'team2': 46,
#  'toss_winner': 53,
#  'winner': 53,
#  'umpire1': 7,
#  'umpire2': 39,
#  'referee': None,
#  'venue': 58,
#  'series': None}

# %%
playersDetail = json.loads(extractData("https://win11.neolen.com/api/player-full"))
type(playersDetail)
# Out:
# list

# %%
playersDetail[758]["bowling_statistics"][0]['player']
# Out:
# 926

# %%
# for x in playersDetail[:]:
#         if x['id']==121:
#             print(json.dumps(x, indent=4))

# %%
def findPlayer(id):
    for x in playersDetail:
        if x['id'] == id:
#             print(json.dumps(x, indent=4))
            return x

def batsmenInMatch(ipl,match_id=0):
    batsmen = []
    try:
        for x in  ipl[match_id]["match_score"][0]["batmens"]:
    #         print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))
              batsmen.append((x['player'],findPlayer(x['player'])['name']))
    except IndexError:
        print("error----------{}".format(x['id']))
        pass
    return batsmen

def bowlersInMatch(ipl,match_id=0):
    bowlers = []
    try:
        for x in  ipl[match_id]["match_score"][0]["bowlers"]:
    #         print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))
              bowlers.append((x['player'],findPlayer(x['player'])['name']))
    except IndexError:
        print("error----------{}".format(x['id']))
        pass
    return bowlers

# %%
def playersInMatch(ipl,match_id=0):
    players = []
    players.append(batsmenInMatch(ipl,match_id))
    players.append(bowlersInMatch(ipl,match_id))
    return players

# %%
# print(json.dumps(findPlayer(87), indent=4))

# %%
# for x in  ipl[0]["match_score"][0]["batmens"]:
#     print("{} --> {}".format(x['player'],findPlayer(x['player'])['name']))

# %%
#  ipl[0]["match_score"][0]["batmens"]

# %%
player = playersInMatch(ipl,191)
len(ipl)
# Out:
# 639

# %%
player[0]
# Out:
# [(423, 'CH Gayle'),
#  (121, 'V Kohli'),
#  (208, 'AB de Villiers'),
#  (806, 'SR Watson')]

# %%
player[1]
# Out:
# [(1431, 'P Kumar'),
#  (867, 'DS Kulkarni'),
#  (1430, 'S Kaushik'),
#  (1434, 'PV Tambe'),
#  (555, 'DJ Bravo'),
#  (119, 'RA Jadeja'),
#  (874, 'DR Smith')]

# %%
playerStatPerMatch = {}
for i,x in enumerate(ipl[:59]):
    players = playersInMatch(ipl,i)
    for j in players[0]:
        playerStatPerMatch.setdefault(j[1],list())
        playerStatPerMatch[j[1]].append(x["id"])
ans = 0
for x,y in list(playerStatPerMatch.items()):
    print(x,len(y))
# Out:
# V Kohli 9
# PA Patel 9
# MM Ali 8
# AB de Villiers 8
# SO Hetmyer 2
# S Dube 1
# C de Grandhomme 1
# NA Saini 2
# YS Chahal 2
# UT Yadav 4
# Mohammed Siraj 3
# DA Warner 6
# JM Bairstow 4
# V Shankar 8
# YK Pathan 4
# MK Pandey 7
# PP Shaw 6
# S Dhawan 6
# SS Iyer 6
# CA Ingram 4
# RR Pant 6
# KMA Paul 4
# AR Patel 6
# R Tewatia 3
# KL Rahul 7
# CH Gayle 6
# MA Agarwal 6
# SN Khan 3
# N Pooran 3
# Mandeep Singh 7
# CA Lynn 8
# SP Narine 6
# RV Uthappa 6
# N Rana 8
# AD Russell 9
# KD Karthik (c) 9
# Q de Kock 9
# RG Sharma 9
# SA Yadav 8
# Yuvraj Singh 3
# KA Pollard 9
# KH Pandya 9
# HH Pandya 9
# MJ McClenaghan 2
# M Markande 2
# JJ Bumrah 1
# AM Rahane 5
# JC Buttler 3
# SV Samson 4
# BA Stokes 4
# NS Naik 1
# Shubman Gill 8
# PP Chawla 5
# Kuldeep Yadav 4
# AT Rayudu 6
# SR Watson 6
# SK Raina 6
# KM Jadhav 3
# MS Dhoni (c) 5
# DJ Bravo 2
# RA Jadeja 3
# SM Curran 5
# DA Miller 4
# GC Viljoen 2
# R Ashwin 4
# M Ashwin 1
# Mohammed Shami 1
# Mujeeb Ur Rahman 2
# MP Stoinis 8
# CH Morris 2
# K Rabada 2
# I Sharma 2
# F du Plessis 5
# Ishan Kishan 2
# RD Chahar 1
# AS Joseph 1
# AD Nath 5
# P Negi 4
# TG Southee 1
# SPD Smith 3
# RA Tripathi 2
# Mohammad Nabi 4
# DJ Hooda 3
# M Prasidh Krishna 1
# HF Gurney 1
# KK Nair 1
# R Parag 3
# JC Archer 1
# S Gopal 2
# JL Denly 1
# CR Brathwaite 2
# C Munro 2
# SW Billings 1
# BCJ Cutting 2
# Harpreet Brar 1
# RK Singh 3
# Y Prithvi Raj 1
# KC Cariappa 1
# DW Steyn 1
# AJ Turner 1
# STR Binny 2
# E Lewis 2
# KS Williamson 4
# Shakib Al Hasan 1
# WP Saha 4
# Rashid Khan 4
# B Kumar 3
# S Kaul 1
# SE Rutherford 2
# Abhishek Sharma 1
# H Klaasen 1
# Gurkeerat Singh 1
# AJ Tye 1
# LS Livingstone 1
# MK Lomror 1
# K Gowtham 1
# IS Sodhi 1
# VR Aaron 1
# MJ Guptill 2
# M Vijay 1
# Basil Thampi 1
# A Mishra 1
# TA Boult 1

# %%
# oak = {'a': 1}
# oak.setdefault('b',list())
# oak.setdefault('b',list())

# oak
#     for j in batsmen[0]:
#         playerStatPerMatch.setdefault(j[1],list())
#         playerStatPerMatch[j[1]].append(x["id"])

# %%
royal_19 = []
for x in ipl[:59]:
    if x['name'].find("royal-challengers") != -1:
#         print("{} --> {}".format(x['id'],x['name']))
        royal_19.append(x)
royal_19[0]['match_score'][0]["batmens"]
# Out:
# [{'id': 17323,
#   'order': 1,
#   'runs': 6,
#   'balls': 12,
#   'strike_rate': 50.0,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'c Jadeja b Harbhajan Singh',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 121,
#   'scorecard': 2225},
#  {'id': 17324,
#   'order': 2,
#   'runs': 29,
#   'balls': 35,
#   'strike_rate': 82.85,
#   'fours': 2,
#   'sixes': 0,
#   'how_out': 'c Jadhav b Bravo',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 1332,
#   'scorecard': 2225},
#  {'id': 17325,
#   'order': 3,
#   'runs': 9,
#   'balls': 8,
#   'strike_rate': 112.5,
#   'fours': 0,
#   'sixes': 1,
#   'how_out': 'c & b Harbhajan Singh',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 87,
#   'scorecard': 2225},
#  {'id': 17326,
#   'order': 4,
#   'runs': 9,
#   'balls': 10,
#   'strike_rate': 90.0,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'c Jadeja b Harbhajan Singh',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 208,
#   'scorecard': 2225},
#  {'id': 17327,
#   'order': 5,
#   'runs': 0,
#   'balls': 2,
#   'strike_rate': 0.0,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'run out (Raina/†Dhoni)',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 271,
#   'scorecard': 2225},
#  {'id': 17328,
#   'order': 6,
#   'runs': 2,
#   'balls': 5,
#   'strike_rate': 40.0,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'c Watson b Imran Tahir',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 349,
#   'scorecard': 2225},
#  {'id': 17329,
#   'order': 7,
#   'runs': 4,
#   'balls': 6,
#   'strike_rate': 66.66,
#   'fours': 1,
#   'sixes': 0,
#   'how_out': 'c †Dhoni b Jadeja',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 158,
#   'scorecard': 2225},
#  {'id': 17330,
#   'order': 8,
#   'runs': 2,
#   'balls': 3,
#   'strike_rate': 66.66,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'c Watson b Imran Tahir',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 358,
#   'scorecard': 2225},
#  {'id': 17331,
#   'order': 9,
#   'runs': 4,
#   'balls': 12,
#   'strike_rate': 33.33,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'c Harbhajan Singh b Imran Tahir',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 346,
#   'scorecard': 2225},
#  {'id': 17332,
#   'order': 10,
#   'runs': 1,
#   'balls': 10,
#   'strike_rate': 10.0,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'b Jadeja',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 137,
#   'scorecard': 2225},
#  {'id': 17333,
#   'order': 11,
#   'runs': 0,
#   'balls': 1,
#   'strike_rate': 0.0,
#   'fours': 0,
#   'sixes': 0,
#   'how_out': 'not out',
#   'fall_of_wicket': None,
#   'fall_of_wicket_over': None,
#   'player': 354,
#   'scorecard': 2225}]

# %%
playerStatPerMatch = {}
for x in royal_19:
    players = []
    batMens = x["match_score"][0]["batmens"]
    bowlers = x["match_score"][0]["bowlers"]
    for batmen in batMens:
        players.append((x['id'],findPlayer(batmen['player'])['name']))
        if findPlayer(batmen['player'])['name'] == 'V Kohli':
            print("{} --> {}".format(x['id'],findPlayer(batmen['player'])['name']))
    for bowler in bowlers:
        players.append((x['id'],findPlayer(bowler['player'])['name']))
        if findPlayer(bowler['player'])['name'] == 'V Kohli':
            print("{} --> {}".format(x['id'],findPlayer(batmen['player'])['name']))
    for j in players:
        playerStatPerMatch.setdefault(j[1],list())
        playerStatPerMatch[j[1]].append(x["id"])
# ans = 0
# for x,y in list(playerStatPerMatch.items()):
#     print(x,len(y))
# Out:
# 1113 --> V Kohli
# 1129 --> V Kohli
# 1132 --> V Kohli
# 1135 --> V Kohli
# 1146 --> V Kohli
# 1150 --> V Kohli
# 1154 --> V Kohli
# 1157 --> V Kohli
# 1164 --> V Kohli
