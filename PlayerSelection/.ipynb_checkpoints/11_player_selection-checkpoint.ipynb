# %% [markdown]
# ## https://www.cricbuzz.com/cricket-series/2849/australia-tour-of-india-2020/matches

# %%
aus_squad = {
    
'batsmen':"Aaron Finch",
'batsmen':"Steven Smith",
'batsmen':"D Arcy Short",
'batsmen':"David Warner",
'batting_allrounder':"Marnus Labuschagne",
'batting_allrounder':"Ashton Turner",
'bowling_allrounder':"Ashton Agar",
'wk-batsmen':"Alex Carey",
'wk-batsmen':"Peter Handscomb",
'bolwer':"Pat Cummins",
'bowler':"Josh Hazlewood",
'bowler':"Kane Richardson",
'bowler':"Mitchell Starc",
'bowler':"Adam Zampa",
}

india_squad = {
'batsmen':"Virat Kohli",
'batsmen':"Rohit Sharma",
'batsmen':"Shikhar Dhawan",
'batsmen':"Shreyas Iyer",
'batsmen':"Manish Pandey",
'batting_allrounder':"Kedar Jadhav",
'bowling_allrounder':"Shivam Dube",
'bowling_allrounder':"Ravindra Jadeja",
'wk-batsmen':"Lokesh Rahul",
'wk-batsmen':"Rishabh Pant",
'wk-batsmen':"Srikar Bharat",
'bowler':"Yuzvendra Chahal",
'bowler':"Kuldeep Yadav",
'bowler':"Navdeep Saini",
'bowler':"Jasprit Bumrah",
'bowler':"Shardul Thakur",
'bowler':"Mohammed Shami",
}

# %%
import json
from statistics import mean

# %%
with open("./india_squad_player_squad_stats.json", encoding='utf-8', errors='ignore') as json_data:
     data = json.load(json_data, strict=False)

# %%
data
# Out:
# {'1': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '2': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '3': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '4': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '5': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '6': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '7': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '8': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '9': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '10': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '11': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '12': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '13': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '14': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '15': {'venue': {'match': 1,
#    'innings': 1,
#    'avg': 42,
#    '5': 0,
#    'wt': 1,
#    '3': 0},
#   'year': {'match': 14, 'innings': 14, 'avg': 24.6, '5': 0, 'wt': 25, '3': 1},
#   'overall': {'match': 64,
#    'innings': 64,
#    'avg': 24.43,
#    '5': 1,
#    'wt': 104,
#    '3': 6},
#   'oponent': {'match': 14,
#    'innings': 14,
#    'avg': 34.83,
#    '5': 0,
#    'wt': 18,
#    '3': 0},
#   '5_match': {'avg': [4.5, 44.0, 13.8, 12.3, 39.0],
#    'wt': [2, 1, 4, 3, 1],
#    '5': [0, 0, 0, 0, 0],
#    '3': [0, 0, 1, 1, 0]}},
#  '16': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}},
#  '17': {'venue': {'match': 5, 'innings': 5, 'avg': 66.2, '50': 1, '100': 1},
#   'year': {'match': 26, 'innings': 25, 'avg': 59.9, '50': 7, '100': 5},
#   'overall': {'match': 241, 'innings': 232, 'avg': 59.3, '50': 58, '100': 43},
#   'oponent': {'match': 40, 'innings': 38, 'avg': 67, '50': 8, '100': 8},
#   '5_match': {'avg': [120.0, 141.0, 4.0, 0.0, 85.0],
#    '50': [0, 0, 0, 0, 1],
#    '100': [1, 1, 0, 0, 0]}}}

# %% [markdown]
# ## Calculating Bating  and Bowling Score

# %%
def batting_score(data,MAX_BATTING_AVG=250,MAX_50_100=3.23): #20*49+5*96
    B = data['avg']/MAX_BATTING_AVG
    C = (20*data['100'] + 5*data['50'])/data['innings']
    print(C,end="")
    D = C/MAX_50_100
    print(D)
    E = 0.4*D + 0.6*B
    return E
def bowling_score(data,MAX_BOWL_AVG=150,MAX_5_3=1.279):
    H = data['avg']/MAX_BOWL_AVG
    F = (20*data['5'] + 5*data['3'])/data['innings']
    G = F/MAX_5_3
    I = 0.4*G + 0.6*H
    return I
def last5_batting_score(data,MAX_BATTING_AVG=250,MAX_50_100=3.23):
    avg = mean(data['avg'])
    max_avg = max(data['avg'])
    fif = sum(data['50'])
    hun = sum(data['100'])
    B = avg/max_avg
    C = (20*hun + 5*fif)/5
    D = C/MAX_50_100
    E = 0.4*D + 0.6*B
    return E
def last5_bowling_score(data,MAX_5_3=1.279):
    avg = mean(data['avg'])
    max_avg = max(data['avg'])
    five_wic = sum(data['5'])
    three_wic = sum(data['3'])
    B = avg/max_avg
    C = (20*five_wic + 5*three_wic)/5
    D = C/MAX_5_3
    E = 0.4*D + 0.6*B
    return E

# %% [markdown]
# ## Calculated Total Score

# %%
def total_batting_score(data):
    overall = data['overall']
    A = overall['innings']/overall['match']
    E = batting_score(overall)
    R = batting_score(data['venue'])
    P = batting_score(data['year'])
    Q = batting_score(data['oponent'])
    L = last5_batting_score(data['5_match'])
    ans = A*((0.25*E) + (0.15*P) + (0.1*(Q+R))+(0.5*L))
    return ans
def total_bowling_score(data):
    overall = data['overall']
    V = overall['innings']/overall['match']
    I = bowling_score(overall)
    S = bowling_score(data['year'])
    T = bowling_score(data['oponent'])
    U = bowling_score(data['venue'])
    L1 = last5_bowling_score(data['5_match'])
    ans = V*((0.25*I) +(0.15*S) + (0.1 *
    (T+U) )+(0.5*L1))
    return ans

# %%
total_batting_score(data['1'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dd8cee1d2b80> in <module>
# ----> 1 total_batting_score(data['1'])
#
# <ipython-input-6-b5fd8fd129fb> in total_batting_score(data)
#       2     overall = data['overall']
#       3     A = overall['innings']/overall['match']
# ----> 4     E = batting_score(overall)
#       5     R = batting_score(data['venue'])
#       6     P = batting_score(data['year'])
#
# <ipython-input-5-2cb2b6337587> in batting_score(data, MAX_BATTING_AVG, MAX_50_100)
#       2     B = data['avg']/MAX_BATTING_AVG
#       3     C = (20*data['100'] + 5*data['50'])/data['innings']
# ----> 4     print(c)
#       5     D = C/MAX_50_100
#       6     E = 0.4*D + 0.6*B
#
# NameError: name 'c' is not defined

# %%
total_bowling_score(data['15'])
